# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rH2nLZjzZtEb9DtNwQpC")
project = rf.workspace("abdullahs-workspace-olp8h").project("license-plate-detection-vpndw")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.2.3 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
pip install -U ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 53.8 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.7
#     Uninstalling widgetsnbextension-3.6.7:
#       Successfully uninstalled widgetsnbextension-3.6.7
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd License-Plate-Detection-1/
# Out:
# /kaggle/working/License-Plate-Detection-1

# %%
# !cat data.yaml
# Out:
# path: ../datasets/roboflow
#
# train: train/images
# val: valid/images
# test: test/images
#
# names:
#   0: licenseplate

# %%
import yaml

# Define the base path
base_path = '/kaggle/working/License-Plate-Detection-1/'

# Path to the data.yaml file
file_path = '/kaggle/working/License-Plate-Detection-1/data.yaml'

# Load the existing YAML file
with open(file_path, 'r') as file:
    data = yaml.safe_load(file)

# Update the paths
data['train'] = f'{base_path}/{data["train"]}'
data['val'] = f'{base_path}/{data["val"]}'
data['test'] = f'{base_path}/{data["test"]}'

# Save the updated YAML file
with open(file_path, 'w') as file:
    yaml.safe_dump(data, file)

print(f"Modified YAML file saved to: {file_path}")
# Out:
# Modified YAML file saved to: /kaggle/working/License-Plate-Detection-1/data.yaml

# %%
# !cat data.yaml
# Out:
# names:
#   0: licenseplate
# path: ../datasets/roboflow
# test: /kaggle/working/License-Plate-Detection-1//test/images
# train: /kaggle/working/License-Plate-Detection-1//train/images
# val: /kaggle/working/License-Plate-Detection-1//valid/images

# %%
# !pip3 install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 30.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-obb.yaml').load('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 150MB/s]
# Transferred 355/397 items from pretrained weights

# %%
results = model.train(data='/kaggle/working/License-Plate-Detection-1/data.yaml',epochs=10,imgsz=640)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.13 torch-2.1.2+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/working/License-Plate-Detection-1/runs/obb/train2/weights/best.pt')

# %%
result = model('/kaggle/working/License-Plate-Detection-1/test/images/uovneg34ahma1_jpg.rf.6b9fb846eff1bcc0db562de9b946ca2f.jpg', save=True)
# Out:
# image 1/1 /kaggle/working/License-Plate-Detection-1/test/images/uovneg34ahma1_jpg.rf.6b9fb846eff1bcc0db562de9b946ca2f.jpg: 640x640 162.4ms
# Speed: 2.6ms preprocess, 162.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/obb/predict3

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the image
image_path = '/kaggle/working/License-Plate-Detection-1/runs/obb/predict3/5ddae55d3e172e14_jpg.rf.2d610ffac7682062a83456431c4a1895.jpg'

# Open the image
image = Image.open(image_path)

# Display the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()

# %%
print(result[0].obb)
# Out:
# ultralytics.engine.results.OBB object with attributes:
#
# cls: tensor([0., 0., 0., 0.])
# conf: tensor([0.91622, 0.90788, 0.86678, 0.83331])
# data: tensor([[4.76712e+01, 2.44741e+02, 6.49987e+01, 5.22794e+01, 5.82945e-02, 9.16219e-01, 0.00000e+00],
#         [2.73483e+02, 6.08641e+02, 1.04829e+02, 6.18046e+01, 4.81291e-02, 9.07877e-01, 0.00000e+00],
#         [4.44953e+02, 2.04553e+02, 7.81783e+01, 7.03246e+01, 8.98085e-02, 8.66778e-01, 0.00000e+00],
#         [2.82721e+02, 3.39505e+02, 8.61874e+01, 6.52164e+01, 3.13201e+00, 8.33314e-01, 0.00000e+00]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([4, 7])
# xywhr: tensor([[4.76712e+01, 2.44741e+02, 6.49987e+01, 5.22794e+01, 5.82945e-02],
#         [2.73483e+02, 6.08641e+02, 1.04829e+02, 6.18046e+01, 4.81291e-02],
#         [4.44953e+02, 2.04553e+02, 7.81783e+01, 7.03246e+01, 8.98085e-02],
#         [2.82721e+02, 3.39505e+02, 8.61874e+01, 6.52164e+01, 3.13201e+00]])
# ...

# %%
print("Bounding box coordinates witb xy and width and height: ",result[0].obb.xywhr)
# Out:
# Bounding box coordinates witb xy and width and height:  tensor([[4.76712e+01, 2.44741e+02, 6.49987e+01, 5.22794e+01, 5.82945e-02],
#         [2.73483e+02, 6.08641e+02, 1.04829e+02, 6.18046e+01, 4.81291e-02],
#         [4.44953e+02, 2.04553e+02, 7.81783e+01, 7.03246e+01, 8.98085e-02],
#         [2.82721e+02, 3.39505e+02, 8.61874e+01, 6.52164e+01, 3.13201e+00]])

# %%
print("Bounding box with all the four coordintes values: ",result[0].obb.xyxyxyxy)
# Out:
# Bounding box with all the four coordintes values:  tensor([[[ 78.59238, 272.72968],
#          [ 81.63827, 220.53909],
#          [ 16.74997, 216.75217],
#          [ 13.70410, 268.94275]],
#
#         [[324.34973, 642.02917],
#          [327.32318, 580.29614],
#          [222.61597, 575.25281],
#          [219.64252, 636.98584]],
#
#         [[480.73138, 243.07950],
#          [487.03864, 173.03833],
#          [409.17535, 166.02670],
#          [402.86810, 236.06787]],
#
#         [[239.31670, 307.31064],
#          [239.94136, 372.52408],
#          [326.12482, 371.69858],
#          [325.50018, 306.48514]]])

# %%
import shutil

# Path to the working directory
working_dir = '/kaggle/working/'

# Path for the output zip file
output_zip = '/kaggle/working/working_files.zip'

# Zip the entire working directory
shutil.make_archive(output_zip.replace('.zip', ''), 'zip', working_dir)

print(f"All files have been zipped into {output_zip}")
# Out:
# All files have been zipped into /kaggle/working/working_files.zip
